# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('noise_test.csv')
signal = data[' Motor Pulse Signal (V)']
data.head()
# Out:
#      Time (s)   Motor Pulse Signal (V)
# 0 -104.606544                -0.024583
# 1 -104.605746                -0.028276
# 2 -104.604948                -0.031970
# 3 -104.604150                -0.028276
# 4 -104.603352                -0.031970

# %%
fs = 1253.01
fft_result = np.fft.fft(signal)
frequencies = np.fft.fftfreq(len(fft_result), 1/fs)

# %%
# Plot the original signal
plt.subplots_adjust(hspace=0.5)
plt.subplot(2, 1, 1)
plt.plot(signal)
plt.title('Original Signal')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')

# Plot the Fourier Transform
plt.subplot(2, 1, 2)
plt.plot(frequencies, np.abs(fft_result))
plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude Spectrum')
# Out:
# Text(0, 0.5, 'Amplitude Spectrum')

# %%
# Plot the Fourier Transform
numPoints = len(fft_result)
plt.plot(frequencies[:numPoints // 2], np.abs(fft_result[:numPoints // 2]))
plt.title('Fourier Transform')
plt.xlabel('Frequency (Hz)')
plt.ylabel('Amplitude Spectrum')
# Out:
# Text(0, 0.5, 'Amplitude Spectrum')
